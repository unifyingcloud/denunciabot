# %% [markdown]
# # This Notebook shows the steps needed to post a carrousel to Facebook

# %% [markdown]
# # Read promotions CSV

# %%
import pandas as pd
file=pd.read_csv("./promotions.csv", error_bad_lines=False, sep=';' )

art1Asin = file["asin"][10] 
art1Price =file["price"][10]
art1Desc=file["node_name"][10]


art2Asin = file["asin"][11] 
art2Price =file["price"][11]
art2Desc=file["node_name"][11]


art3Asin = file["asin"][12] 
art3Price =file["price"][12]
art3Desc=file["node_name"][12]


file.head()
# Out:
#     id       node_id        asin  \
# 0  0.0  9.757451e+09  B01M8L3JLY
# 1  1.0  9.757451e+09  B01MEHSMXD
# 2  2.0  9.757451e+09  B001TA3OCQ
# 3  3.0  9.757451e+09  B01MYMQ94L
# 4  4.0  9.757451e+09  B00MYL7PF6
#
#                                                title  sales_rank  \
# 0  Stylemaster Home Products MEMPHIS Reversible S...         NaN
# 1  Stylemaster Home Products MEMPHIS Reversible S...         NaN
# 2  Kingston Brass DR910243 Designer Trimscape Geo...         NaN
# 3              2-Pc Twin Quilt Set in Navy and White         NaN
# 4  Olive Kids Trains, Planes, Trucks Toddler Shee...     20820.0
#
#   percentage_saved amount_saved   list_price    price  \
# 0                1     20160928  20161208,32   278,99
# 1                1  20160910,08  20161208,32   296,91
# 2             0,69      4788,35      6910,48  2122,13
# 3             0,76      4296,68      5688,57  1391,89
# 4             0,77      2522,99      3285,06   762,07
#
#                                         availability       ...         \
# 0  Temporarily out of stock. Order now and we'll ...       ...
# 1  Temporarily out of stock. Order now and we'll ...       ...
# 2                        Se suele enviar en 24 horas       ...
# 3                        Se suele enviar en 24 horas       ...
# 4                        Se suele enviar en 24 horas       ...
#
#                                             features  features_brand  \
# 0  2 Attractive colors: Midnight, wine\nCare inst...     Stylemaster
# 1  2 Attractive colors: midnight, Wine\nCare inst...     Stylemaster
# 2  Brass with Aluminum Construction\nMounting har...  Kingston Brass
# 3  Includes one quilt and one pillow sham\nStripe...      Lush Decor
# 4  Includes top sheet, fitted sheet and 1 pillow ...      Olive Kids
#
#                  features_binding features_department features_product_group  \
# 0                          Cocina                 NaN                Kitchen
# 1                          Cocina                 NaN                Kitchen
# 2  Herramientas y mejora de hogar                 NaN       Home Improvement
# 3                          Cocina                 NaN                   Home
# 4                         Juguete      Adulto, unisex                    Toy
#
#   features_release_date        parent              node_name  \
# 0                   NaN  9.757431e+09  Ropa de Cama Infantil
# 1                   NaN  9.757431e+09  Ropa de Cama Infantil
# 2                   NaN  9.757431e+09  Ropa de Cama Infantil
# 3                   NaN  9.757431e+09  Ropa de Cama Infantil
# 4                   NaN  9.757431e+09  Ropa de Cama Infantil
#
#              parent_name        root_node
# 0  Blancos para el Hogar  Hogar y  Cocina
# 1  Blancos para el Hogar  Hogar y  Cocina
# 2  Blancos para el Hogar  Hogar y  Cocina
# 3  Blancos para el Hogar  Hogar y  Cocina
# 4  Blancos para el Hogar  Hogar y  Cocina
#
# [5 rows x 24 columns]

# %%
# !pip install python-amazon-simple-product-api
# Out:
# Collecting python-amazon-simple-product-api
#   Downloading python-amazon-simple-product-api-2.2.11.tar.gz
# Collecting bottlenose (from python-amazon-simple-product-api)
#   Downloading bottlenose-1.1.7-py2.py3-none-any.whl
# Requirement already satisfied: lxml in /Users/jonatancisnerosrodriguez/anaconda3/lib/python3.6/site-packages (from python-amazon-simple-product-api)
# Requirement already satisfied: python-dateutil in /Users/jonatancisnerosrodriguez/anaconda3/lib/python3.6/site-packages (from python-amazon-simple-product-api)
# Requirement already satisfied: six>=1.5 in /Users/jonatancisnerosrodriguez/anaconda3/lib/python3.6/site-packages (from python-dateutil->python-amazon-simple-product-api)
# Building wheels for collected packages: python-amazon-simple-product-api
#   Running setup.py bdist_wheel for python-amazon-simple-product-api ... done
#   Stored in directory: /Users/jonatancisnerosrodriguez/Library/Caches/pip/wheels/68/9a/ee/9d12fba1840534e0f09e2fc69299bb0c5e4b862608c8ee01da
# Successfully built python-amazon-simple-product-api
# Installing collected packages: bottlenose, python-amazon-simple-product-api
# Successfully installed bottlenose-1.1.7 python-amazon-simple-product-api-2.2.11

# %% [markdown]
# # Use AMAZON API to lookup products

# %%
# aws_access_key_id=AKIAISFUXK5KKJBPA4DA
# aws_secret_access_key=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
# aws_associate_tag=descuentosn0b-20
import urllib.request
from amazon.api import AmazonAPI
amazon = AmazonAPI('AKIAISFUXK5KKJBPA4DA', 'zPc67zmBSHtM4Zgxn9hW40JvFVN/JpwLdkwxF/X2', 'descuentosn0b-20',region='MX')
art1Amazon=amazon.lookup(ItemId=art1Asin)
art2Amazon=amazon.lookup(ItemId=art2Asin)
art3Amazon=amazon.lookup(ItemId=art3Asin)



urllib.request.urlretrieve(art1Amazon.large_image_url, "image1.png")
urllib.request.urlretrieve(art2Amazon.large_image_url, "image2.png")
urllib.request.urlretrieve(art3Amazon.large_image_url, "image3.png")

art1Amazon.small_image_url
# Out:
# 'https://images-na.ssl-images-amazon.com/images/I/41L-8lmAbGL._SL75_.jpg'

# %%
from facebookads.adobjects.adaccount import AdAccount
from facebookads.adobjects.campaign import Campaign
from facebookads.adobjects.adset import AdSet
from facebookads.adobjects.adcreative import AdCreative
from facebookads.adobjects.ad import Ad
from facebookads.adobjects.adpreview import AdPreview
from facebookads.api import FacebookAdsApi
from facebookads.adobjects.adimage import AdImage
from facebookads.adobjects.adcreativeobjectstoryspec import AdCreativeObjectStorySpec
from facebookads.adobjects.adcreativelinkdatachildattachment import AdCreativeLinkDataChildAttachment
from facebookads.adobjects.adcreativelinkdata import AdCreativeLinkData

access_token = 'EAAcx8J3ioXsBABVWZAjbKjnnuDxjBkQYRWR0bgP8nXcRzCueVMLl2Ls79Mb0PZBddMVBKAXXcULMlxk7yPZBfZBzUubvV8kOkBn8Wt0rnCcKS0W0KCEAYj4JSHLeWX4rumD6g4bZCZARfYLaeAJiPKZAb4hFwinr6z2tXdfgpGLwoYsjrCBELVWFQDdUWGQEHQ2tF8yv1ByD0tD5ZBtcofCw'
ad_account_id = 'act_124574458345290'
app_secret = '4e3189df82df5b65fd9ddb715fbd3c49'
page_id = '1456225704491934'
app_id = '2025234347762043'
FacebookAdsApi.init(access_token=access_token)



fields = [
]
params = {
    'objective': 'PAGE_LIKES',
    'status': 'PAUSED',
    'buying_type': 'AUCTION',
    'name': 'My Campaign',
}
campaign = AdAccount(ad_account_id).create_campaign(
    fields=fields,
    params=params,
)
print ('campaign', campaign)

campaign_id = campaign.get_id()
print ('campaign_id:', campaign_id, '\n')

fields = [
]
params = {
    'status': 'PAUSED',
    'targeting': {'geo_locations':{'countries':['MX']}},
    'daily_budget': '100',
    'billing_event': 'IMPRESSIONS',
    'bid_amount': '20',
    'campaign_id': campaign_id,
    'optimization_goal': 'PAGE_LIKES',
    'promoted_object': {'page_id': page_id},
    'name': 'My AdSet',
}
ad_set = AdAccount(ad_account_id).create_ad_set(
    fields=fields,
    params=params,
)
print ('ad_set', ad_set)

ad_set_id = ad_set.get_id()
print ('ad_set_id:', ad_set_id, '\n')
fields = [
]


 


image = AdImage(parent_id=ad_account_id)
image[AdImage.Field.filename] = "image1.png"
image.remote_create()



product1 = AdCreativeLinkDataChildAttachment()
product1[AdCreativeLinkDataChildAttachment.Field.link] = art1Amazon.small_image_url
product1[AdCreativeLinkDataChildAttachment.Field.name] = art1Amazon.title
product1[AdCreativeLinkDataChildAttachment.Field.description] = art1Price
product1[AdCreativeLinkDataChildAttachment.Field.image_hash] =image[AdImage.Field.hash];

image2 = AdImage(parent_id=ad_account_id)
image2[AdImage.Field.filename] = "image2.png"
image2.remote_create()





product2 = AdCreativeLinkDataChildAttachment()
product2[AdCreativeLinkDataChildAttachment.Field.link] = art2Amazon.small_image_url
product2[AdCreativeLinkDataChildAttachment.Field.name] = art2Amazon.title
product2[AdCreativeLinkDataChildAttachment.Field.description] = art2Price
product2[AdCreativeLinkDataChildAttachment.Field.image_hash] = image2[AdImage.Field.hash]


image3 = AdImage(parent_id=ad_account_id)
image3[AdImage.Field.filename] = "image3.png"
image3.remote_create()

product3 = AdCreativeLinkDataChildAttachment()
product3[AdCreativeLinkDataChildAttachment.Field.link] = art3Amazon.small_image_url
product3[AdCreativeLinkDataChildAttachment.Field.name] = art3Amazon.title
product3[AdCreativeLinkDataChildAttachment.Field.description] = art3Price
product3[AdCreativeLinkDataChildAttachment.Field.image_hash] = image3[AdImage.Field.hash]


link = AdCreativeLinkData()
link[link.Field.link] = 'http://www.facebookmarketingdevelopers.com/static/images' 
link[link.Field.child_attachments] = [product1, product2, product3]

story = AdCreativeObjectStorySpec()
story[story.Field.page_id] = '1456225704491934'
story[story.Field.link_data] =  link
 

# creative = AdAccount(ad_account_id).create_ad_creative(
#     fields=fields,
#     params=params 
# )

creative = AdCreative(parent_id=ad_account_id)
creative[AdCreative.Field.name] = 'Test Creative'
creative[AdCreative.Field.object_story_spec] = story
creative.remote_create()
 

print ('creative', creative)

creative_id = creative.get_id()
print ('creative_id:', creative_id, '\n')

fields = [
]
params = {
    'status': 'PAUSED',
    'adset_id': ad_set_id,
    'name': 'My Ad',
    'creative': {'creative_id':creative_id},
}
ad = AdAccount(ad_account_id).create_ad(
    fields=fields,
    params=params,
)
print ('ad', ad)

ad_id = ad.get_id()
print ('ad_id:', ad_id, '\n')

fields = [
]
params = {
    'ad_format': 'DESKTOP_FEED_STANDARD',
}
resultPreview =Ad(ad_id).get_previews(
    fields=fields,
    params=params,
)
# Out:
# campaign <Campaign> {
#     "id": "120330000023640416"
# }
# campaign_id: 120330000023640416
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# ad_set <AdSet> {
#     "id": "120330000023640916"
# }
# ad_set_id: 120330000023640916
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# creative <AdCreative> {
#     "creative_id": "120330000023641016",
#     "id": "120330000023641016",
#     "name": "Test Creative",
#     "object_story_spec": {
#         "link_data": {
#             "child_attachments": [
#                 {
#                     "description": "502,18",
#                     "image_hash": "8a7d8f93b4ec9bf10020345790094e10",
#                     "link": "https://images-na.ssl-images-amazon.com/images/I/41L-8lmAbGL._SL75_.jpg",
#                     "name": "Impressions C800KGPC SLSG 800 Thread Count, 100% Cotton, Single Ply, 2-Piece King Pillowcase Set, Solid, Sage"
#                 },
#                 {
#                     "description": "288,14",
#                     "image_hash": "120ad87307be05377e8e3edb33ec983e",
#                     "link": "https://images-na.ssl-images-amazon.com/images/I/316EMFigcuL._SL75_.jpg",
#                     "name": "Superior, 600 Thread Count,  100% Premium Long-Staple Combed Cotton, 2-Piece Standard Pillowcase Set, embroidery Greek Key, beige"
#                 },
#                 {
#                     "description": "435,65",
#                     "image_hash": "273ce597533740f89a0427602438cfed",
#                     "link": "https://images-na.ssl-images-amazon.com/images/I/41xbqddWDBL._SL75_.jpg",
#                     "name": "Superior,  100% Premium Long-Staple Combed Cotton, 650 Thread Count, King 2-Piece Pillowcase Set, Single Ply, Solid, grey"
#                 }
#             ],
#             "link": "http://www.facebookmarketingdevelopers.com/static/images"
#         },
#         "page_id": "1456225704491934"
#     }
# }
# creative_id: 120330000023641016
#
# ad <Ad> {
#     "id": "120330000023641716"
# }
# ad_id: 120330000023641716

# %%
resultPreview[0]
# Out:
# <AdPreview> {
#     "body": "<iframe src=\"https://www.facebook.com/ads/api/preview_iframe.php?d=AQI0rBTdFfCHr-sYfWKmILGoX-8xEDeWVu7d5k5skS2t_NR4FysW6h7frQkDToX7vOkhpJ25zwkCw01JDEMo1KEYrBWxoEbvMQM6u9w9GT4qfFxBxgJye4z-aGjhQAJJ2rVZs1gpHOVQ5mQcjfPKUoRu2DjX7x4_YcOx5zMGuzUd0DkgajO5AAWrJVU6jbKmOYApJ-pWva4YY38QLkzWwxltGctVzDDSbywDKjoqoyvhuqimFrX0Osf2pYwplL8LdFnw4yC2y-aAbQzCk3yk8vW0&amp;t=AQIhEgBWBiBijkHX\" width=\"540\" height=\"690\" scrolling=\"yes\" style=\"border: none;\"></iframe>"
# }
